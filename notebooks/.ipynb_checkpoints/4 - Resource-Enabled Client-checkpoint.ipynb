# %%
# !pip install requests
# Out:
# Requirement already satisfied: requests in /Users/heya.world/Desktop/PythonAndSpotifyAPI/venv/lib/python3.8/site-packages (2.24.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /Users/heya.world/Desktop/PythonAndSpotifyAPI/venv/lib/python3.8/site-packages (from requests) (1.25.11)
# Requirement already satisfied: chardet<4,>=3.0.2 in /Users/heya.world/Desktop/PythonAndSpotifyAPI/venv/lib/python3.8/site-packages (from requests) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /Users/heya.world/Desktop/PythonAndSpotifyAPI/venv/lib/python3.8/site-packages (from requests) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/heya.world/Desktop/PythonAndSpotifyAPI/venv/lib/python3.8/site-packages (from requests) (2020.6.20)

# %%
import requests #you can use the curl command as well
import datetime
from urllib.parse import urlencode

# %%
import base64

# %%
client_id = 'a0b548bd1bd64de2b3277d9dc4d12923'
client_secret = '5b9544235a6243eca69907df30149128'

# %%
class SpotifyAPI(object):
    access_token = None
    access_token_expires = datetime.datetime.now()
    access_token_did_expire = True 
    client_id = None
    client_secret = None 
    token_url = "https://accounts.spotify.com/api/token"
    
    def __init__(self, client_id, client_secret, *args, **kwargs):
        super().__init__(*args, **kwargs) 
        self.client_id = client_id
        self.client_secret = client_secret
        
    def get_client_credentials(self):
        """
        Returns a base64 encoded string
        """
        client_id = self.client_id
        client_secret = self.client_secret
        if client_id == None or client_secret == None:
            raise Exception ('you must set client id or client secret')
        client_creds = f"{client_id}:{client_secret}"
        client_creds_b64 = base64.b64encode(client_creds.encode())
        return client_creds_b64.decode()
    
    def get_token_headers(self):
        client_creds_b64 = self.get_client_credentials()
        return {
            "Authorization": f"Basic {client_creds_b64}" 
        }
    
    def get_token_data(self):
        return {
            "grant_type": "client_credentials"
        }
    def perform_auth(self):
        token_url = self.token_url
        token_data = self.get_token_data()
        token_headers = self.get_token_headers()
        r = requests.post(token_url, data=token_data, headers=token_headers)

        if r.status_code not in range (200,299):
            raise Exception("Could not authenticate client.")
            #return False
        data = r.json()
        now = datetime.datetime.now() #gives you the exact current time
        access_token = data['access_token']
        expires_in = data['expires_in'] #seconds
        expires = now + datetime.timedelta(seconds=expires_in) #gives back datetime object relative to now
        self.access_token = access_token
        self.access_token_expires = expires
        self.access_token_did_expire = expires < now
        return True
    
    def get_access_token(self):
        #auth.done = self.perform_auth()
        #if not auth_done:
            #raise Exception("auth failed")
        token = self.access_token
        expires = self.access_token_expires
        now = datetime.datetime.now()
        if expires < now:
            self.perform_auth()
            return self.get_access_token()
        elif token == None:
            self.perform_auth()
            return self.get_access_token()
        return token
    
    def get_resource_header(self):
        access_token = self.get_access_token()
        headers = {
            "Authorization": f"Bearer {access_token}"
        }
        return headers
    
    def get_resource(self, lookup_id, resource_type='albums', version='v1'):
        endpoint = f"https://api.spotify.com/{version}/{resource_type}/{lookup_id}"
        headers = self.get_resource_header()
        r = requests.get(endpoint, headers=headers)
        if r.status_code not in range(200,299):
            return {}
        reutrn r.json()
    
    def get_album(self, _id):
        return self.get_resource(_id, resource_type='albums')
    
    def get_artist(self, _id):
        return self.get_resource(_id, resource_type='artists')
    
    def search(self, query, search_type='artist'): #type
        headers = self.get_resource_header()
        endpoint = "https://api.spotify.com/v1/search"
        data = urlencode({"q": query, "type":search_type.lower()})
        lookup_url = f"{endpoint}?{data}" 
        print(lookup_url)
        r = requests.get(lookup_url, headers=headers)
        if r.status_code in range (200,299):
            return r.json() 
        return {} #return empty lookup

# %%
spotify = SpotifyAPI(client_id, client_secret)

# %%
spotify.search("heya ㅎㅇ", search_type="track")
# Out:
# https://api.spotify.com/v1/search?q=heya+%E3%85%8E%E3%85%87&type=track
# {'tracks': {'href': 'https://api.spotify.com/v1/search?query=heya+%E3%85%8E%E3%85%87&type=track&offset=0&limit=20',
#   'items': [{'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5UfeYtslz7DT0hvVnkCEjB'},
#        'href': 'https://api.spotify.com/v1/artists/5UfeYtslz7DT0hvVnkCEjB',
#        'id': '5UfeYtslz7DT0hvVnkCEjB',
#        'name': 'Penthouse Penthouse',
#        'type': 'artist',
#        'uri': 'spotify:artist:5UfeYtslz7DT0hvVnkCEjB'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/00RTzPyOnRKHjxlfR8f4AB'},
#        'href': 'https://api.spotify.com/v1/artists/00RTzPyOnRKHjxlfR8f4AB',
#        'id': '00RTzPyOnRKHjxlfR8f4AB',
#        'name': 'heya ㅎㅇ',
#        'type': 'artist',
#        'uri': 'spotify:artist:00RTzPyOnRKHjxlfR8f4AB'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/56IRf5wCw2lwCfyahXThqE'},
#      'href': 'https://api.spotify.com/v1/albums/56IRf5wCw2lwCfyahXThqE',
#      'id': '56IRf5wCw2lwCfyahXThqE',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273093e0efaa3bcec99f62b137d',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02093e0efaa3bcec99f62b137d',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851093e0efaa3bcec99f62b137d',
#        'width': 64}],
#      'name': 'Figaro',
#      'release_date': '2019-06-07',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:56IRf5wCw2lwCfyahXThqE'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5UfeYtslz7DT0hvVnkCEjB'},
#       'href': 'https://api.spotify.com/v1/artists/5UfeYtslz7DT0hvVnkCEjB',
#       'id': '5UfeYtslz7DT0hvVnkCEjB',
#       'name': 'Penthouse Penthouse',
#       'type': 'artist',
#       'uri': 'spotify:artist:5UfeYtslz7DT0hvVnkCEjB'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/00RTzPyOnRKHjxlfR8f4AB'},
#       'href': 'https://api.spotify.com/v1/artists/00RTzPyOnRKHjxlfR8f4AB',
#       'id': '00RTzPyOnRKHjxlfR8f4AB',
#       'name': 'heya ㅎㅇ',
#       'type': 'artist',
#       'uri': 'spotify:artist:00RTzPyOnRKHjxlfR8f4AB'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 296074,
#     'explicit': False,
#     'external_ids': {'isrc': 'TCAEF1997117'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1vxTWvOt2vnd9yyqNia2tQ'},
#     'href': 'https://api.spotify.com/v1/tracks/1vxTWvOt2vnd9yyqNia2tQ',
#     'id': '1vxTWvOt2vnd9yyqNia2tQ',
#     'is_local': False,
#     'name': 'Figaro',
#     'popularity': 5,
#     'preview_url': 'https://p.scdn.co/mp3-preview/a52ce221adbabb82f5787fba0ca6e0aeb65933b3?cid=a0b548bd1bd64de2b3277d9dc4d12923',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:1vxTWvOt2vnd9yyqNia2tQ'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/00RTzPyOnRKHjxlfR8f4AB'},
#        'href': 'https://api.spotify.com/v1/artists/00RTzPyOnRKHjxlfR8f4AB',
#        'id': '00RTzPyOnRKHjxlfR8f4AB',
#        'name': 'heya ㅎㅇ',
#        'type': 'artist',
#        'uri': 'spotify:artist:00RTzPyOnRKHjxlfR8f4AB'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2XiRBxy9vo7idjxlbiJyDv'},
#      'href': 'https://api.spotify.com/v1/albums/2XiRBxy9vo7idjxlbiJyDv',
#      'id': '2XiRBxy9vo7idjxlbiJyDv',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2738a0ae535b6203046a0ec57dc',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e028a0ae535b6203046a0ec57dc',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048518a0ae535b6203046a0ec57dc',
#        'width': 64}],
#      'name': 'Yi-Gun Deep Hous-U',
#      'release_date': '2018-05-26',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:2XiRBxy9vo7idjxlbiJyDv'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/00RTzPyOnRKHjxlfR8f4AB'},
#       'href': 'https://api.spotify.com/v1/artists/00RTzPyOnRKHjxlfR8f4AB',
#       'id': '00RTzPyOnRKHjxlfR8f4AB',
#       'name': 'heya ㅎㅇ',
#       'type': 'artist',
#       'uri': 'spotify:artist:00RTzPyOnRKHjxlfR8f4AB'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 242016,
#     'explicit': False,
#     'external_ids': {'isrc': 'QZB4J1898796'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/7xR37dhlcdHn1vmnrZw8XS'},
#     'href': 'https://api.spotify.com/v1/tracks/7xR37dhlcdHn1vmnrZw8XS',
#     'id': '7xR37dhlcdHn1vmnrZw8XS',
#     'is_local': False,
#     'name': 'Yi-Gun Deep Hous-U',
#     'popularity': 0,
#     'preview_url': 'https://p.scdn.co/mp3-preview/fd914cf216cc9ed00816a3fe340b984c5a2000b1?cid=a0b548bd1bd64de2b3277d9dc4d12923',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:7xR37dhlcdHn1vmnrZw8XS'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/00RTzPyOnRKHjxlfR8f4AB'},
#        'href': 'https://api.spotify.com/v1/artists/00RTzPyOnRKHjxlfR8f4AB',
#        'id': '00RTzPyOnRKHjxlfR8f4AB',
#        'name': 'heya ㅎㅇ',
#        'type': 'artist',
#        'uri': 'spotify:artist:00RTzPyOnRKHjxlfR8f4AB'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/1LSlvSVmky5X7VMMlyaNIe'},
#        'href': 'https://api.spotify.com/v1/artists/1LSlvSVmky5X7VMMlyaNIe',
#        'id': '1LSlvSVmky5X7VMMlyaNIe',
#        'name': 'Sacha K.',
#        'type': 'artist',
#        'uri': 'spotify:artist:1LSlvSVmky5X7VMMlyaNIe'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/13e89yEbgfguwdttXPPKaQ'},
#      'href': 'https://api.spotify.com/v1/albums/13e89yEbgfguwdttXPPKaQ',
#      'id': '13e89yEbgfguwdttXPPKaQ',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2732e1cebc6cb6eb3e8e93278c3',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e022e1cebc6cb6eb3e8e93278c3',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048512e1cebc6cb6eb3e8e93278c3',
#        'width': 64}],
#      'name': 'Yi-Gun Deep Hous-U (Sacha K. Remix)',
#      'release_date': '2018-06-05',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:13e89yEbgfguwdttXPPKaQ'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/00RTzPyOnRKHjxlfR8f4AB'},
#       'href': 'https://api.spotify.com/v1/artists/00RTzPyOnRKHjxlfR8f4AB',
#       'id': '00RTzPyOnRKHjxlfR8f4AB',
#       'name': 'heya ㅎㅇ',
#       'type': 'artist',
#       'uri': 'spotify:artist:00RTzPyOnRKHjxlfR8f4AB'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/1LSlvSVmky5X7VMMlyaNIe'},
#       'href': 'https://api.spotify.com/v1/artists/1LSlvSVmky5X7VMMlyaNIe',
#       'id': '1LSlvSVmky5X7VMMlyaNIe',
#       'name': 'Sacha K.',
#       'type': 'artist',
#       'uri': 'spotify:artist:1LSlvSVmky5X7VMMlyaNIe'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 161016,
#     'explicit': False,
#     'external_ids': {'isrc': 'QZDA41850792'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2SzX5Ipyrg9llsI0j9qSt6'},
#     'href': 'https://api.spotify.com/v1/tracks/2SzX5Ipyrg9llsI0j9qSt6',
#     'id': '2SzX5Ipyrg9llsI0j9qSt6',
#     'is_local': False,
#     'name': 'Yi-Gun Deep Hous-U - Sacha K. Remix',
#     'popularity': 0,
#     'preview_url': 'https://p.scdn.co/mp3-preview/e713781eff3e672c22b5ed0afeab26ab230899c0?cid=a0b548bd1bd64de2b3277d9dc4d12923',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:2SzX5Ipyrg9llsI0j9qSt6'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/00RTzPyOnRKHjxlfR8f4AB'},
#        'href': 'https://api.spotify.com/v1/artists/00RTzPyOnRKHjxlfR8f4AB',
#        'id': '00RTzPyOnRKHjxlfR8f4AB',
#        'name': 'heya ㅎㅇ',
#        'type': 'artist',
#        'uri': 'spotify:artist:00RTzPyOnRKHjxlfR8f4AB'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6ZIcNrBSwwla3aU4TcEogf'},
#      'href': 'https://api.spotify.com/v1/albums/6ZIcNrBSwwla3aU4TcEogf',
#      'id': '6ZIcNrBSwwla3aU4TcEogf',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273eafd61ebb2e4c27b574c52f2',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02eafd61ebb2e4c27b574c52f2',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851eafd61ebb2e4c27b574c52f2',
#        'width': 64}],
#      'name': 'Gum',
#      'release_date': '2018-08-28',
#      'release_date_precision': 'day',
#      'total_tracks': 6,
#      'type': 'album',
#      'uri': 'spotify:album:6ZIcNrBSwwla3aU4TcEogf'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/00RTzPyOnRKHjxlfR8f4AB'},
#       'href': 'https://api.spotify.com/v1/artists/00RTzPyOnRKHjxlfR8f4AB',
#       'id': '00RTzPyOnRKHjxlfR8f4AB',
#       'name': 'heya ㅎㅇ',
#       'type': 'artist',
#       'uri': 'spotify:artist:00RTzPyOnRKHjxlfR8f4AB'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 214565,
#     'explicit': False,
#     'external_ids': {'isrc': 'QMPKX1838889'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6Qf7VfI07zCM3AQ4oIx5wo'},
#     'href': 'https://api.spotify.com/v1/tracks/6Qf7VfI07zCM3AQ4oIx5wo',
#     'id': '6Qf7VfI07zCM3AQ4oIx5wo',
#     'is_local': False,
#     'name': 'Sneakers',
#     'popularity': 0,
#     'preview_url': 'https://p.scdn.co/mp3-preview/e06c6ba940b813f6ce32cdb853c6da4762dd6bbc?cid=a0b548bd1bd64de2b3277d9dc4d12923',
#     'track_number': 4,
#     'type': 'track',
#     'uri': 'spotify:track:6Qf7VfI07zCM3AQ4oIx5wo'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/00RTzPyOnRKHjxlfR8f4AB'},
#        'href': 'https://api.spotify.com/v1/artists/00RTzPyOnRKHjxlfR8f4AB',
#        'id': '00RTzPyOnRKHjxlfR8f4AB',
#        'name': 'heya ㅎㅇ',
#        'type': 'artist',
#        'uri': 'spotify:artist:00RTzPyOnRKHjxlfR8f4AB'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/14DeSBncFu9yGVw8cY9s0a'},
#      'href': 'https://api.spotify.com/v1/albums/14DeSBncFu9yGVw8cY9s0a',
#      'id': '14DeSBncFu9yGVw8cY9s0a',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273caa96c8ca58b369cffa382de',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02caa96c8ca58b369cffa382de',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851caa96c8ca58b369cffa382de',
#        'width': 64}],
#      'name': 'Caake',
#      'release_date': '2020-01-24',
#      'release_date_precision': 'day',
#      'total_tracks': 3,
#      'type': 'album',
#      'uri': 'spotify:album:14DeSBncFu9yGVw8cY9s0a'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/00RTzPyOnRKHjxlfR8f4AB'},
#       'href': 'https://api.spotify.com/v1/artists/00RTzPyOnRKHjxlfR8f4AB',
#       'id': '00RTzPyOnRKHjxlfR8f4AB',
#       'name': 'heya ㅎㅇ',
#       'type': 'artist',
#       'uri': 'spotify:artist:00RTzPyOnRKHjxlfR8f4AB'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 192077,
#     'explicit': False,
#     'external_ids': {'isrc': 'QZFYY2017108'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/178uWu9I4nE9YC5hFVEvRX'},
#     'href': 'https://api.spotify.com/v1/tracks/178uWu9I4nE9YC5hFVEvRX',
#     'id': '178uWu9I4nE9YC5hFVEvRX',
#     'is_local': False,
#     'name': 'Gi-Do (Prayers)',
#     'popularity': 0,
#     'preview_url': 'https://p.scdn.co/mp3-preview/f72c2b41bc6142f1c252e720e64828f07d07aced?cid=a0b548bd1bd64de2b3277d9dc4d12923',
#     'track_number': 3,
#     'type': 'track',
#     'uri': 'spotify:track:178uWu9I4nE9YC5hFVEvRX'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/00RTzPyOnRKHjxlfR8f4AB'},
#        'href': 'https://api.spotify.com/v1/artists/00RTzPyOnRKHjxlfR8f4AB',
#        'id': '00RTzPyOnRKHjxlfR8f4AB',
#        'name': 'heya ㅎㅇ',
#        'type': 'artist',
#        'uri': 'spotify:artist:00RTzPyOnRKHjxlfR8f4AB'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6ZIcNrBSwwla3aU4TcEogf'},
#      'href': 'https://api.spotify.com/v1/albums/6ZIcNrBSwwla3aU4TcEogf',
#      'id': '6ZIcNrBSwwla3aU4TcEogf',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273eafd61ebb2e4c27b574c52f2',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02eafd61ebb2e4c27b574c52f2',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851eafd61ebb2e4c27b574c52f2',
#        'width': 64}],
#      'name': 'Gum',
#      'release_date': '2018-08-28',
#      'release_date_precision': 'day',
#      'total_tracks': 6,
#      'type': 'album',
#      'uri': 'spotify:album:6ZIcNrBSwwla3aU4TcEogf'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/00RTzPyOnRKHjxlfR8f4AB'},
#       'href': 'https://api.spotify.com/v1/artists/00RTzPyOnRKHjxlfR8f4AB',
#       'id': '00RTzPyOnRKHjxlfR8f4AB',
#       'name': 'heya ㅎㅇ',
#       'type': 'artist',
#       'uri': 'spotify:artist:00RTzPyOnRKHjxlfR8f4AB'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 149302,
#     'explicit': False,
#     'external_ids': {'isrc': 'QMPKX1838886'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3atDovGYhJ3q93tcUUkffm'},
#     'href': 'https://api.spotify.com/v1/tracks/3atDovGYhJ3q93tcUUkffm',
#     'id': '3atDovGYhJ3q93tcUUkffm',
#     'is_local': False,
#     'name': 'Honey, the Floor Is Wet',
#     'popularity': 0,
#     'preview_url': 'https://p.scdn.co/mp3-preview/c7307e47e4a4b5330962241cd4c3f866022c94fd?cid=a0b548bd1bd64de2b3277d9dc4d12923',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:3atDovGYhJ3q93tcUUkffm'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/00RTzPyOnRKHjxlfR8f4AB'},
#        'href': 'https://api.spotify.com/v1/artists/00RTzPyOnRKHjxlfR8f4AB',
#        'id': '00RTzPyOnRKHjxlfR8f4AB',
#        'name': 'heya ㅎㅇ',
#        'type': 'artist',
#        'uri': 'spotify:artist:00RTzPyOnRKHjxlfR8f4AB'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6ZIcNrBSwwla3aU4TcEogf'},
#      'href': 'https://api.spotify.com/v1/albums/6ZIcNrBSwwla3aU4TcEogf',
#      'id': '6ZIcNrBSwwla3aU4TcEogf',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273eafd61ebb2e4c27b574c52f2',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02eafd61ebb2e4c27b574c52f2',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851eafd61ebb2e4c27b574c52f2',
#        'width': 64}],
#      'name': 'Gum',
#      'release_date': '2018-08-28',
#      'release_date_precision': 'day',
#      'total_tracks': 6,
#      'type': 'album',
#      'uri': 'spotify:album:6ZIcNrBSwwla3aU4TcEogf'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/00RTzPyOnRKHjxlfR8f4AB'},
#       'href': 'https://api.spotify.com/v1/artists/00RTzPyOnRKHjxlfR8f4AB',
#       'id': '00RTzPyOnRKHjxlfR8f4AB',
#       'name': 'heya ㅎㅇ',
#       'type': 'artist',
#       'uri': 'spotify:artist:00RTzPyOnRKHjxlfR8f4AB'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/1zHqjOEF9knpsD2Z7mEpU4'},
#       'href': 'https://api.spotify.com/v1/artists/1zHqjOEF9knpsD2Z7mEpU4',
#       'id': '1zHqjOEF9knpsD2Z7mEpU4',
#       'name': 'Allieyxo',
#       'type': 'artist',
#       'uri': 'spotify:artist:1zHqjOEF9knpsD2Z7mEpU4'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/7JpH0NVw05QL82I9cw28TZ'},
#       'href': 'https://api.spotify.com/v1/artists/7JpH0NVw05QL82I9cw28TZ',
#       'id': '7JpH0NVw05QL82I9cw28TZ',
#       'name': 'Geomi',
#       'type': 'artist',
#       'uri': 'spotify:artist:7JpH0NVw05QL82I9cw28TZ'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 173068,
#     'explicit': False,
#     'external_ids': {'isrc': 'QMPKX1838888'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/38Bnq6aw4pmTfLstmBHZd2'},
#     'href': 'https://api.spotify.com/v1/tracks/38Bnq6aw4pmTfLstmBHZd2',
#     'id': '38Bnq6aw4pmTfLstmBHZd2',
#     'is_local': False,
#     'name': 'Small Talks',
#     'popularity': 0,
#     'preview_url': 'https://p.scdn.co/mp3-preview/b54642753fb69b1d709177d4afdff9e791bb8e0f?cid=a0b548bd1bd64de2b3277d9dc4d12923',
#     'track_number': 3,
#     'type': 'track',
#     'uri': 'spotify:track:38Bnq6aw4pmTfLstmBHZd2'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/00RTzPyOnRKHjxlfR8f4AB'},
#        'href': 'https://api.spotify.com/v1/artists/00RTzPyOnRKHjxlfR8f4AB',
#        'id': '00RTzPyOnRKHjxlfR8f4AB',
#        'name': 'heya ㅎㅇ',
#        'type': 'artist',
#        'uri': 'spotify:artist:00RTzPyOnRKHjxlfR8f4AB'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6ZIcNrBSwwla3aU4TcEogf'},
#      'href': 'https://api.spotify.com/v1/albums/6ZIcNrBSwwla3aU4TcEogf',
#      'id': '6ZIcNrBSwwla3aU4TcEogf',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273eafd61ebb2e4c27b574c52f2',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02eafd61ebb2e4c27b574c52f2',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851eafd61ebb2e4c27b574c52f2',
#        'width': 64}],
#      'name': 'Gum',
#      'release_date': '2018-08-28',
#      'release_date_precision': 'day',
#      'total_tracks': 6,
#      'type': 'album',
#      'uri': 'spotify:album:6ZIcNrBSwwla3aU4TcEogf'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/00RTzPyOnRKHjxlfR8f4AB'},
#       'href': 'https://api.spotify.com/v1/artists/00RTzPyOnRKHjxlfR8f4AB',
#       'id': '00RTzPyOnRKHjxlfR8f4AB',
#       'name': 'heya ㅎㅇ',
#       'type': 'artist',
#       'uri': 'spotify:artist:00RTzPyOnRKHjxlfR8f4AB'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 165642,
#     'explicit': False,
#     'external_ids': {'isrc': 'QMPKX1838887'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/19tkvcU0hXluaLymxB2yij'},
#     'href': 'https://api.spotify.com/v1/tracks/19tkvcU0hXluaLymxB2yij',
#     'id': '19tkvcU0hXluaLymxB2yij',
#     'is_local': False,
#     'name': 'Mint Ice Cream',
#     'popularity': 0,
#     'preview_url': 'https://p.scdn.co/mp3-preview/36ee00ec12581c5f0ece61e7ff9845fb256e236f?cid=a0b548bd1bd64de2b3277d9dc4d12923',
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:19tkvcU0hXluaLymxB2yij'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/00RTzPyOnRKHjxlfR8f4AB'},
#        'href': 'https://api.spotify.com/v1/artists/00RTzPyOnRKHjxlfR8f4AB',
#        'id': '00RTzPyOnRKHjxlfR8f4AB',
#        'name': 'heya ㅎㅇ',
#        'type': 'artist',
#        'uri': 'spotify:artist:00RTzPyOnRKHjxlfR8f4AB'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6ZIcNrBSwwla3aU4TcEogf'},
#      'href': 'https://api.spotify.com/v1/albums/6ZIcNrBSwwla3aU4TcEogf',
#      'id': '6ZIcNrBSwwla3aU4TcEogf',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273eafd61ebb2e4c27b574c52f2',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02eafd61ebb2e4c27b574c52f2',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851eafd61ebb2e4c27b574c52f2',
#        'width': 64}],
#      'name': 'Gum',
#      'release_date': '2018-08-28',
#      'release_date_precision': 'day',
#      'total_tracks': 6,
#      'type': 'album',
#      'uri': 'spotify:album:6ZIcNrBSwwla3aU4TcEogf'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/00RTzPyOnRKHjxlfR8f4AB'},
#       'href': 'https://api.spotify.com/v1/artists/00RTzPyOnRKHjxlfR8f4AB',
#       'id': '00RTzPyOnRKHjxlfR8f4AB',
#       'name': 'heya ㅎㅇ',
#       'type': 'artist',
#       'uri': 'spotify:artist:00RTzPyOnRKHjxlfR8f4AB'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 60000,
#     'explicit': False,
#     'external_ids': {'isrc': 'QMPKX1838890'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0Qxy26po5viiQJ71EanqiN'},
#     'href': 'https://api.spotify.com/v1/tracks/0Qxy26po5viiQJ71EanqiN',
#     'id': '0Qxy26po5viiQJ71EanqiN',
#     'is_local': False,
#     'name': 'Outro..?',
#     'popularity': 0,
#     'preview_url': 'https://p.scdn.co/mp3-preview/d8119c63993daf5552f4534f4ba0e7cca72a4c95?cid=a0b548bd1bd64de2b3277d9dc4d12923',
#     'track_number': 5,
#     'type': 'track',
#     'uri': 'spotify:track:0Qxy26po5viiQJ71EanqiN'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/00RTzPyOnRKHjxlfR8f4AB'},
#        'href': 'https://api.spotify.com/v1/artists/00RTzPyOnRKHjxlfR8f4AB',
#        'id': '00RTzPyOnRKHjxlfR8f4AB',
#        'name': 'heya ㅎㅇ',
#        'type': 'artist',
#        'uri': 'spotify:artist:00RTzPyOnRKHjxlfR8f4AB'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6ytDbABxmaWF1bOrrJZpCO'},
#      'href': 'https://api.spotify.com/v1/albums/6ytDbABxmaWF1bOrrJZpCO',
#      'id': '6ytDbABxmaWF1bOrrJZpCO',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27302f4101676064f49edb68e61',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0202f4101676064f49edb68e61',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485102f4101676064f49edb68e61',
#        'width': 64}],
#      'name': 'Angel Baby Luv',
#      'release_date': '2019-10-25',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:6ytDbABxmaWF1bOrrJZpCO'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/00RTzPyOnRKHjxlfR8f4AB'},
#       'href': 'https://api.spotify.com/v1/artists/00RTzPyOnRKHjxlfR8f4AB',
#       'id': '00RTzPyOnRKHjxlfR8f4AB',
#       'name': 'heya ㅎㅇ',
#       'type': 'artist',
#       'uri': 'spotify:artist:00RTzPyOnRKHjxlfR8f4AB'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 212224,
#     'explicit': False,
#     'external_ids': {'isrc': 'QZHN81984124'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0i51zbLwEq0UVA0JYcFcEq'},
#     'href': 'https://api.spotify.com/v1/tracks/0i51zbLwEq0UVA0JYcFcEq',
#     'id': '0i51zbLwEq0UVA0JYcFcEq',
#     'is_local': False,
#     'name': 'Angel Baby Luv',
#     'popularity': 0,
#     'preview_url': 'https://p.scdn.co/mp3-preview/f483fd9899cca52ee850a6c296f0b32bcd645914?cid=a0b548bd1bd64de2b3277d9dc4d12923',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:0i51zbLwEq0UVA0JYcFcEq'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/00RTzPyOnRKHjxlfR8f4AB'},
#        'href': 'https://api.spotify.com/v1/artists/00RTzPyOnRKHjxlfR8f4AB',
#        'id': '00RTzPyOnRKHjxlfR8f4AB',
#        'name': 'heya ㅎㅇ',
#        'type': 'artist',
#        'uri': 'spotify:artist:00RTzPyOnRKHjxlfR8f4AB'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/14DeSBncFu9yGVw8cY9s0a'},
#      'href': 'https://api.spotify.com/v1/albums/14DeSBncFu9yGVw8cY9s0a',
#      'id': '14DeSBncFu9yGVw8cY9s0a',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273caa96c8ca58b369cffa382de',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02caa96c8ca58b369cffa382de',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851caa96c8ca58b369cffa382de',
#        'width': 64}],
#      'name': 'Caake',
#      'release_date': '2020-01-24',
#      'release_date_precision': 'day',
#      'total_tracks': 3,
#      'type': 'album',
#      'uri': 'spotify:album:14DeSBncFu9yGVw8cY9s0a'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/00RTzPyOnRKHjxlfR8f4AB'},
#       'href': 'https://api.spotify.com/v1/artists/00RTzPyOnRKHjxlfR8f4AB',
#       'id': '00RTzPyOnRKHjxlfR8f4AB',
#       'name': 'heya ㅎㅇ',
#       'type': 'artist',
#       'uri': 'spotify:artist:00RTzPyOnRKHjxlfR8f4AB'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 212224,
#     'explicit': False,
#     'external_ids': {'isrc': 'QZHN81984124'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4Pbjpwgkv1rwuN8wFWtjP6'},
#     'href': 'https://api.spotify.com/v1/tracks/4Pbjpwgkv1rwuN8wFWtjP6',
#     'id': '4Pbjpwgkv1rwuN8wFWtjP6',
#     'is_local': False,
#     'name': 'Angel Baby Luv',
#     'popularity': 0,
#     'preview_url': 'https://p.scdn.co/mp3-preview/9ca71366290e65433a0772bf9ab2fa224fa39e16?cid=a0b548bd1bd64de2b3277d9dc4d12923',
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:4Pbjpwgkv1rwuN8wFWtjP6'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/00RTzPyOnRKHjxlfR8f4AB'},
#        'href': 'https://api.spotify.com/v1/artists/00RTzPyOnRKHjxlfR8f4AB',
#        'id': '00RTzPyOnRKHjxlfR8f4AB',
#        'name': 'heya ㅎㅇ',
#        'type': 'artist',
#        'uri': 'spotify:artist:00RTzPyOnRKHjxlfR8f4AB'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/14DeSBncFu9yGVw8cY9s0a'},
#      'href': 'https://api.spotify.com/v1/albums/14DeSBncFu9yGVw8cY9s0a',
#      'id': '14DeSBncFu9yGVw8cY9s0a',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273caa96c8ca58b369cffa382de',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02caa96c8ca58b369cffa382de',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851caa96c8ca58b369cffa382de',
#        'width': 64}],
#      'name': 'Caake',
#      'release_date': '2020-01-24',
#      'release_date_precision': 'day',
#      'total_tracks': 3,
#      'type': 'album',
#      'uri': 'spotify:album:14DeSBncFu9yGVw8cY9s0a'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/00RTzPyOnRKHjxlfR8f4AB'},
#       'href': 'https://api.spotify.com/v1/artists/00RTzPyOnRKHjxlfR8f4AB',
#       'id': '00RTzPyOnRKHjxlfR8f4AB',
#       'name': 'heya ㅎㅇ',
#       'type': 'artist',
#       'uri': 'spotify:artist:00RTzPyOnRKHjxlfR8f4AB'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 142413,
#     'explicit': False,
#     'external_ids': {'isrc': 'QZFYY2017107'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0ZRxjey9fcQ5BgoaLEA7Lt'},
#     'href': 'https://api.spotify.com/v1/tracks/0ZRxjey9fcQ5BgoaLEA7Lt',
#     'id': '0ZRxjey9fcQ5BgoaLEA7Lt',
#     'is_local': False,
#     'name': 'Milk',
#     'popularity': 0,
#     'preview_url': 'https://p.scdn.co/mp3-preview/9809807bae0b09cc67e527d0f8691a4801427924?cid=a0b548bd1bd64de2b3277d9dc4d12923',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:0ZRxjey9fcQ5BgoaLEA7Lt'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/00RTzPyOnRKHjxlfR8f4AB'},
#        'href': 'https://api.spotify.com/v1/artists/00RTzPyOnRKHjxlfR8f4AB',
#        'id': '00RTzPyOnRKHjxlfR8f4AB',
#        'name': 'heya ㅎㅇ',
#        'type': 'artist',
#        'uri': 'spotify:artist:00RTzPyOnRKHjxlfR8f4AB'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6ZIcNrBSwwla3aU4TcEogf'},
#      'href': 'https://api.spotify.com/v1/albums/6ZIcNrBSwwla3aU4TcEogf',
#      'id': '6ZIcNrBSwwla3aU4TcEogf',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273eafd61ebb2e4c27b574c52f2',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02eafd61ebb2e4c27b574c52f2',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851eafd61ebb2e4c27b574c52f2',
#        'width': 64}],
#      'name': 'Gum',
#      'release_date': '2018-08-28',
#      'release_date_precision': 'day',
#      'total_tracks': 6,
#      'type': 'album',
#      'uri': 'spotify:album:6ZIcNrBSwwla3aU4TcEogf'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/00RTzPyOnRKHjxlfR8f4AB'},
#       'href': 'https://api.spotify.com/v1/artists/00RTzPyOnRKHjxlfR8f4AB',
#       'id': '00RTzPyOnRKHjxlfR8f4AB',
#       'name': 'heya ㅎㅇ',
#       'type': 'artist',
#       'uri': 'spotify:artist:00RTzPyOnRKHjxlfR8f4AB'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/68Lhj6c90DQr2Mjxs4rfXR'},
#       'href': 'https://api.spotify.com/v1/artists/68Lhj6c90DQr2Mjxs4rfXR',
#       'id': '68Lhj6c90DQr2Mjxs4rfXR',
#       'name': 'YERV',
#       'type': 'artist',
#       'uri': 'spotify:artist:68Lhj6c90DQr2Mjxs4rfXR'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 144000,
#     'explicit': True,
#     'external_ids': {'isrc': 'QMPKX1838891'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6ZEC6zG51UxayUx2GnjqtF'},
#     'href': 'https://api.spotify.com/v1/tracks/6ZEC6zG51UxayUx2GnjqtF',
#     'id': '6ZEC6zG51UxayUx2GnjqtF',
#     'is_local': False,
#     'name': 'Corgi A$$',
#     'popularity': 0,
#     'preview_url': 'https://p.scdn.co/mp3-preview/ed336ad80c4cfe6f8d401f04896adef64503a9f0?cid=a0b548bd1bd64de2b3277d9dc4d12923',
#     'track_number': 6,
#     'type': 'track',
#     'uri': 'spotify:track:6ZEC6zG51UxayUx2GnjqtF'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/11LIo6r4T2rsXfUVEgDEDe'},
#        'href': 'https://api.spotify.com/v1/artists/11LIo6r4T2rsXfUVEgDEDe',
#        'id': '11LIo6r4T2rsXfUVEgDEDe',
#        'name': 'Miles French',
#        'type': 'artist',
#        'uri': 'spotify:artist:11LIo6r4T2rsXfUVEgDEDe'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2Qf0OS0GU8bKxVL7luYR2a'},
#      'href': 'https://api.spotify.com/v1/albums/2Qf0OS0GU8bKxVL7luYR2a',
#      'id': '2Qf0OS0GU8bKxVL7luYR2a',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2734df3555cf12cb5c4ea9bc1b9',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e024df3555cf12cb5c4ea9bc1b9',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048514df3555cf12cb5c4ea9bc1b9',
#        'width': 64}],
#      'name': 'Void Demos',
#      'release_date': '2019-06-28',
#      'release_date_precision': 'day',
#      'total_tracks': 4,
#      'type': 'album',
#      'uri': 'spotify:album:2Qf0OS0GU8bKxVL7luYR2a'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/11LIo6r4T2rsXfUVEgDEDe'},
#       'href': 'https://api.spotify.com/v1/artists/11LIo6r4T2rsXfUVEgDEDe',
#       'id': '11LIo6r4T2rsXfUVEgDEDe',
#       'name': 'Miles French',
#       'type': 'artist',
#       'uri': 'spotify:artist:11LIo6r4T2rsXfUVEgDEDe'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/0q8fjIJygzfNjN1ndsySjK'},
#       'href': 'https://api.spotify.com/v1/artists/0q8fjIJygzfNjN1ndsySjK',
#       'id': '0q8fjIJygzfNjN1ndsySjK',
#       'name': 'heya ᄒᄋ',
#       'type': 'artist',
#       'uri': 'spotify:artist:0q8fjIJygzfNjN1ndsySjK'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 174193,
#     'explicit': True,
#     'external_ids': {'isrc': 'QZGLS1998565'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4z9uk3r7OQIhM8LgCgRsKt'},
#     'href': 'https://api.spotify.com/v1/tracks/4z9uk3r7OQIhM8LgCgRsKt',
#     'id': '4z9uk3r7OQIhM8LgCgRsKt',
#     'is_local': False,
#     'name': 'I Just Lannded',
#     'popularity': 0,
#     'preview_url': 'https://p.scdn.co/mp3-preview/45019ae3c13eb782cab4619e2fb74e9a1f1e69ee?cid=a0b548bd1bd64de2b3277d9dc4d12923',
#     'track_number': 4,
#     'type': 'track',
#     'uri': 'spotify:track:4z9uk3r7OQIhM8LgCgRsKt'}],
#   'limit': 20,
#   'next': None,
#   'offset': 0,
#   'previous': None,
#   'total': 14}}
