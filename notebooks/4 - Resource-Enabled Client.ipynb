# %%
# !pip install requests
# Out:
# Requirement already satisfied: requests in /Users/heya.world/Desktop/PythonAndSpotifyAPI/venv/lib/python3.8/site-packages (2.24.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/heya.world/Desktop/PythonAndSpotifyAPI/venv/lib/python3.8/site-packages (from requests) (2020.6.20)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /Users/heya.world/Desktop/PythonAndSpotifyAPI/venv/lib/python3.8/site-packages (from requests) (1.25.11)
# Requirement already satisfied: chardet<4,>=3.0.2 in /Users/heya.world/Desktop/PythonAndSpotifyAPI/venv/lib/python3.8/site-packages (from requests) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /Users/heya.world/Desktop/PythonAndSpotifyAPI/venv/lib/python3.8/site-packages (from requests) (2.10)

# %%
import requests #you can use the curl command as well
import datetime
from urllib.parse import urlencode

# %%
import base64

# %%
client_id = 'a0b548bd1bd64de2b3277d9dc4d12923'
client_secret = '5b9544235a6243eca69907df30149128'

# %%
class SpotifyAPI(object):
    access_token = None
    access_token_expires = datetime.datetime.now()
    access_token_did_expire = True 
    client_id = None
    client_secret = None 
    token_url = "https://accounts.spotify.com/api/token"
    
    def __init__(self, client_id, client_secret, *args, **kwargs):
        super().__init__(*args, **kwargs) 
        self.client_id = client_id
        self.client_secret = client_secret
        
    def get_client_credentials(self):
        """
        Returns a base64 encoded string
        """
        client_id = self.client_id
        client_secret = self.client_secret
        if client_id == None or client_secret == None:
            raise Exception ('you must set client id or client secret')
        client_creds = f"{client_id}:{client_secret}"
        client_creds_b64 = base64.b64encode(client_creds.encode())
        return client_creds_b64.decode()
    
    def get_token_headers(self):
        client_creds_b64 = self.get_client_credentials()
        return {
            "Authorization": f"Basic {client_creds_b64}" 
        }
    
    def get_token_data(self):
        return {
            "grant_type": "client_credentials"
        }
    def perform_auth(self):
        token_url = self.token_url
        token_data = self.get_token_data()
        token_headers = self.get_token_headers()
        r = requests.post(token_url, data=token_data, headers=token_headers)

        if r.status_code not in range (200,299):
            raise Exception("Could not authenticate client.")
            #return False
        data = r.json()
        now = datetime.datetime.now() #gives you the exact current time
        access_token = data['access_token']
        expires_in = data['expires_in'] #seconds
        expires = now + datetime.timedelta(seconds=expires_in) #gives back datetime object relative to now
        self.access_token = access_token
        self.access_token_expires = expires
        self.access_token_did_expire = expires < now
        return True
    
    def get_access_token(self):
        #auth.done = self.perform_auth()
        #if not auth_done:
            #raise Exception("auth failed")
        token = self.access_token
        expires = self.access_token_expires
        now = datetime.datetime.now()
        if expires < now:
            self.perform_auth()
            return self.get_access_token()
        elif token == None:
            self.perform_auth()
            return self.get_access_token()
        return token
    
    def get_resource_header(self):
        access_token = self.get_access_token()
        headers = {
            "Authorization": f"Bearer {access_token}"
        }
        return headers
    
    def get_resource(self, lookup_id, resource_type='albums', version='v1'):
        endpoint = f"https://api.spotify.com/{version}/{resource_type}/{lookup_id}"
        headers = self.get_resource_header()
        r = requests.get(endpoint, headers=headers)
        if r.status_code not in range(200,299):
            return {}
        return r.json()
    
    def get_album(self, _id):
        return self.get_resource(_id, resource_type='albums')
    
    def get_artist(self, _id):
        return self.get_resource(_id, resource_type='artists')
    
    def search(self, query, search_type='artist'): #type
        headers = self.get_resource_header()
        endpoint = "https://api.spotify.com/v1/search"
        data = urlencode({"q": query, "type":search_type.lower()})
        lookup_url = f"{endpoint}?{data}" 
        print(lookup_url)
        r = requests.get(lookup_url, headers=headers)
        if r.status_code in range (200,299):
            return r.json() 
        return {} #return empty lookup

# %%
spotify = SpotifyAPI(client_id, client_secret)

# %%
spotify.search("amine", search_type="track")
# Out:
# https://api.spotify.com/v1/search?q=amine&type=track
# {'tracks': {'href': 'https://api.spotify.com/v1/search?query=amine&type=track&offset=0&limit=20',
#   'items': [{'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3Gm5F95VdRxW3mqCn8RPBJ'},
#        'href': 'https://api.spotify.com/v1/artists/3Gm5F95VdRxW3mqCn8RPBJ',
#        'id': '3Gm5F95VdRxW3mqCn8RPBJ',
#        'name': 'Aminé',
#        'type': 'artist',
#        'uri': 'spotify:artist:3Gm5F95VdRxW3mqCn8RPBJ'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4mwO9qIVmngSe7yR5Ios0I'},
#      'href': 'https://api.spotify.com/v1/albums/4mwO9qIVmngSe7yR5Ios0I',
#      'id': '4mwO9qIVmngSe7yR5Ios0I',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273a52fb68f00620e45ed7467c5',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02a52fb68f00620e45ed7467c5',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851a52fb68f00620e45ed7467c5',
#        'width': 64}],
#      'name': 'ONEPOINTFIVE',
#      'release_date': '2018-08-15',
#      'release_date_precision': 'day',
#      'total_tracks': 13,
#      'type': 'album',
#      'uri': 'spotify:album:4mwO9qIVmngSe7yR5Ios0I'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3Gm5F95VdRxW3mqCn8RPBJ'},
#       'href': 'https://api.spotify.com/v1/artists/3Gm5F95VdRxW3mqCn8RPBJ',
#       'id': '3Gm5F95VdRxW3mqCn8RPBJ',
#       'name': 'Aminé',
#       'type': 'artist',
#       'uri': 'spotify:artist:3Gm5F95VdRxW3mqCn8RPBJ'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 121346,
#     'explicit': True,
#     'external_ids': {'isrc': 'USUM71811853'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5qHirGR7M9tdm6C17DlzSY'},
#     'href': 'https://api.spotify.com/v1/tracks/5qHirGR7M9tdm6C17DlzSY',
#     'id': '5qHirGR7M9tdm6C17DlzSY',
#     'is_local': False,
#     'name': 'REEL IT IN',
#     'popularity': 77,
#     'preview_url': None,
#     'track_number': 3,
#     'type': 'track',
#     'uri': 'spotify:track:5qHirGR7M9tdm6C17DlzSY'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3Gm5F95VdRxW3mqCn8RPBJ'},
#        'href': 'https://api.spotify.com/v1/artists/3Gm5F95VdRxW3mqCn8RPBJ',
#        'id': '3Gm5F95VdRxW3mqCn8RPBJ',
#        'name': 'Aminé',
#        'type': 'artist',
#        'uri': 'spotify:artist:3Gm5F95VdRxW3mqCn8RPBJ'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3lajefIuUk4SfzqVBSJy8p'},
#      'href': 'https://api.spotify.com/v1/albums/3lajefIuUk4SfzqVBSJy8p',
#      'id': '3lajefIuUk4SfzqVBSJy8p',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27360282020360f5048976275aa',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0260282020360f5048976275aa',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485160282020360f5048976275aa',
#        'width': 64}],
#      'name': 'Good For You',
#      'release_date': '2017-07-28',
#      'release_date_precision': 'day',
#      'total_tracks': 15,
#      'type': 'album',
#      'uri': 'spotify:album:3lajefIuUk4SfzqVBSJy8p'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3Gm5F95VdRxW3mqCn8RPBJ'},
#       'href': 'https://api.spotify.com/v1/artists/3Gm5F95VdRxW3mqCn8RPBJ',
#       'id': '3Gm5F95VdRxW3mqCn8RPBJ',
#       'name': 'Aminé',
#       'type': 'artist',
#       'uri': 'spotify:artist:3Gm5F95VdRxW3mqCn8RPBJ'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 209640,
#     'explicit': True,
#     'external_ids': {'isrc': 'USCGH1697037'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5hTpBe8h35rJ67eAWHQsJx'},
#     'href': 'https://api.spotify.com/v1/tracks/5hTpBe8h35rJ67eAWHQsJx',
#     'id': '5hTpBe8h35rJ67eAWHQsJx',
#     'is_local': False,
#     'name': 'Caroline',
#     'popularity': 76,
#     'preview_url': None,
#     'track_number': 3,
#     'type': 'track',
#     'uri': 'spotify:track:5hTpBe8h35rJ67eAWHQsJx'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3Gm5F95VdRxW3mqCn8RPBJ'},
#        'href': 'https://api.spotify.com/v1/artists/3Gm5F95VdRxW3mqCn8RPBJ',
#        'id': '3Gm5F95VdRxW3mqCn8RPBJ',
#        'name': 'Aminé',
#        'type': 'artist',
#        'uri': 'spotify:artist:3Gm5F95VdRxW3mqCn8RPBJ'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6a8GwYiEMrXgMvZBvuBXrt'},
#      'href': 'https://api.spotify.com/v1/albums/6a8GwYiEMrXgMvZBvuBXrt',
#      'id': '6a8GwYiEMrXgMvZBvuBXrt',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273ea9bbdf9f1433e68c7dffbad',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02ea9bbdf9f1433e68c7dffbad',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851ea9bbdf9f1433e68c7dffbad',
#        'width': 64}],
#      'name': 'Limbo',
#      'release_date': '2020-08-07',
#      'release_date_precision': 'day',
#      'total_tracks': 14,
#      'type': 'album',
#      'uri': 'spotify:album:6a8GwYiEMrXgMvZBvuBXrt'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3Gm5F95VdRxW3mqCn8RPBJ'},
#       'href': 'https://api.spotify.com/v1/artists/3Gm5F95VdRxW3mqCn8RPBJ',
#       'id': '3Gm5F95VdRxW3mqCn8RPBJ',
#       'name': 'Aminé',
#       'type': 'artist',
#       'uri': 'spotify:artist:3Gm5F95VdRxW3mqCn8RPBJ'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 143152,
#     'explicit': True,
#     'external_ids': {'isrc': 'USUM72013373'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4FFC7McrnnwAWKbAqbckTP'},
#     'href': 'https://api.spotify.com/v1/tracks/4FFC7McrnnwAWKbAqbckTP',
#     'id': '4FFC7McrnnwAWKbAqbckTP',
#     'is_local': False,
#     'name': 'Woodlawn',
#     'popularity': 71,
#     'preview_url': None,
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:4FFC7McrnnwAWKbAqbckTP'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3Gm5F95VdRxW3mqCn8RPBJ'},
#        'href': 'https://api.spotify.com/v1/artists/3Gm5F95VdRxW3mqCn8RPBJ',
#        'id': '3Gm5F95VdRxW3mqCn8RPBJ',
#        'name': 'Aminé',
#        'type': 'artist',
#        'uri': 'spotify:artist:3Gm5F95VdRxW3mqCn8RPBJ'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6a8GwYiEMrXgMvZBvuBXrt'},
#      'href': 'https://api.spotify.com/v1/albums/6a8GwYiEMrXgMvZBvuBXrt',
#      'id': '6a8GwYiEMrXgMvZBvuBXrt',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273ea9bbdf9f1433e68c7dffbad',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02ea9bbdf9f1433e68c7dffbad',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851ea9bbdf9f1433e68c7dffbad',
#        'width': 64}],
#      'name': 'Limbo',
#      'release_date': '2020-08-07',
#      'release_date_precision': 'day',
#      'total_tracks': 14,
#      'type': 'album',
#      'uri': 'spotify:album:6a8GwYiEMrXgMvZBvuBXrt'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3Gm5F95VdRxW3mqCn8RPBJ'},
#       'href': 'https://api.spotify.com/v1/artists/3Gm5F95VdRxW3mqCn8RPBJ',
#       'id': '3Gm5F95VdRxW3mqCn8RPBJ',
#       'name': 'Aminé',
#       'type': 'artist',
#       'uri': 'spotify:artist:3Gm5F95VdRxW3mqCn8RPBJ'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/50co4Is1HCEo8bhOyUWKpn'},
#       'href': 'https://api.spotify.com/v1/artists/50co4Is1HCEo8bhOyUWKpn',
#       'id': '50co4Is1HCEo8bhOyUWKpn',
#       'name': 'Young Thug',
#       'type': 'artist',
#       'uri': 'spotify:artist:50co4Is1HCEo8bhOyUWKpn'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 197855,
#     'explicit': True,
#     'external_ids': {'isrc': 'USUM72013235'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/61KoN6PlBhQD7sivCcf0hA'},
#     'href': 'https://api.spotify.com/v1/tracks/61KoN6PlBhQD7sivCcf0hA',
#     'id': '61KoN6PlBhQD7sivCcf0hA',
#     'is_local': False,
#     'name': 'Compensating (feat. Young Thug)',
#     'popularity': 70,
#     'preview_url': None,
#     'track_number': 6,
#     'type': 'track',
#     'uri': 'spotify:track:61KoN6PlBhQD7sivCcf0hA'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3Gm5F95VdRxW3mqCn8RPBJ'},
#        'href': 'https://api.spotify.com/v1/artists/3Gm5F95VdRxW3mqCn8RPBJ',
#        'id': '3Gm5F95VdRxW3mqCn8RPBJ',
#        'name': 'Aminé',
#        'type': 'artist',
#        'uri': 'spotify:artist:3Gm5F95VdRxW3mqCn8RPBJ'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3lajefIuUk4SfzqVBSJy8p'},
#      'href': 'https://api.spotify.com/v1/albums/3lajefIuUk4SfzqVBSJy8p',
#      'id': '3lajefIuUk4SfzqVBSJy8p',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27360282020360f5048976275aa',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0260282020360f5048976275aa',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485160282020360f5048976275aa',
#        'width': 64}],
#      'name': 'Good For You',
#      'release_date': '2017-07-28',
#      'release_date_precision': 'day',
#      'total_tracks': 15,
#      'type': 'album',
#      'uri': 'spotify:album:3lajefIuUk4SfzqVBSJy8p'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3Gm5F95VdRxW3mqCn8RPBJ'},
#       'href': 'https://api.spotify.com/v1/artists/3Gm5F95VdRxW3mqCn8RPBJ',
#       'id': '3Gm5F95VdRxW3mqCn8RPBJ',
#       'name': 'Aminé',
#       'type': 'artist',
#       'uri': 'spotify:artist:3Gm5F95VdRxW3mqCn8RPBJ'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 173946,
#     'explicit': True,
#     'external_ids': {'isrc': 'USUG11700903'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4HW5kSQ8M2IQWZhSxERvla'},
#     'href': 'https://api.spotify.com/v1/tracks/4HW5kSQ8M2IQWZhSxERvla',
#     'id': '4HW5kSQ8M2IQWZhSxERvla',
#     'is_local': False,
#     'name': 'Spice Girl',
#     'popularity': 69,
#     'preview_url': None,
#     'track_number': 5,
#     'type': 'track',
#     'uri': 'spotify:track:4HW5kSQ8M2IQWZhSxERvla'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3Gm5F95VdRxW3mqCn8RPBJ'},
#        'href': 'https://api.spotify.com/v1/artists/3Gm5F95VdRxW3mqCn8RPBJ',
#        'id': '3Gm5F95VdRxW3mqCn8RPBJ',
#        'name': 'Aminé',
#        'type': 'artist',
#        'uri': 'spotify:artist:3Gm5F95VdRxW3mqCn8RPBJ'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3lajefIuUk4SfzqVBSJy8p'},
#      'href': 'https://api.spotify.com/v1/albums/3lajefIuUk4SfzqVBSJy8p',
#      'id': '3lajefIuUk4SfzqVBSJy8p',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27360282020360f5048976275aa',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0260282020360f5048976275aa',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485160282020360f5048976275aa',
#        'width': 64}],
#      'name': 'Good For You',
#      'release_date': '2017-07-28',
#      'release_date_precision': 'day',
#      'total_tracks': 15,
#      'type': 'album',
#      'uri': 'spotify:album:3lajefIuUk4SfzqVBSJy8p'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3Gm5F95VdRxW3mqCn8RPBJ'},
#       'href': 'https://api.spotify.com/v1/artists/3Gm5F95VdRxW3mqCn8RPBJ',
#       'id': '3Gm5F95VdRxW3mqCn8RPBJ',
#       'name': 'Aminé',
#       'type': 'artist',
#       'uri': 'spotify:artist:3Gm5F95VdRxW3mqCn8RPBJ'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/0cGUm45nv7Z6M6qdXYQGTX'},
#       'href': 'https://api.spotify.com/v1/artists/0cGUm45nv7Z6M6qdXYQGTX',
#       'id': '0cGUm45nv7Z6M6qdXYQGTX',
#       'name': 'Kehlani',
#       'type': 'artist',
#       'uri': 'spotify:artist:0cGUm45nv7Z6M6qdXYQGTX'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 220160,
#     'explicit': True,
#     'external_ids': {'isrc': 'USUG11700787'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/32xx0fAv3CIeGmNaWTHvEF'},
#     'href': 'https://api.spotify.com/v1/tracks/32xx0fAv3CIeGmNaWTHvEF',
#     'id': '32xx0fAv3CIeGmNaWTHvEF',
#     'is_local': False,
#     'name': 'Heebiejeebies - Bonus',
#     'popularity': 67,
#     'preview_url': None,
#     'track_number': 15,
#     'type': 'track',
#     'uri': 'spotify:track:32xx0fAv3CIeGmNaWTHvEF'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3Gm5F95VdRxW3mqCn8RPBJ'},
#        'href': 'https://api.spotify.com/v1/artists/3Gm5F95VdRxW3mqCn8RPBJ',
#        'id': '3Gm5F95VdRxW3mqCn8RPBJ',
#        'name': 'Aminé',
#        'type': 'artist',
#        'uri': 'spotify:artist:3Gm5F95VdRxW3mqCn8RPBJ'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6a8GwYiEMrXgMvZBvuBXrt'},
#      'href': 'https://api.spotify.com/v1/albums/6a8GwYiEMrXgMvZBvuBXrt',
#      'id': '6a8GwYiEMrXgMvZBvuBXrt',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273ea9bbdf9f1433e68c7dffbad',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02ea9bbdf9f1433e68c7dffbad',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851ea9bbdf9f1433e68c7dffbad',
#        'width': 64}],
#      'name': 'Limbo',
#      'release_date': '2020-08-07',
#      'release_date_precision': 'day',
#      'total_tracks': 14,
#      'type': 'album',
#      'uri': 'spotify:album:6a8GwYiEMrXgMvZBvuBXrt'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3Gm5F95VdRxW3mqCn8RPBJ'},
#       'href': 'https://api.spotify.com/v1/artists/3Gm5F95VdRxW3mqCn8RPBJ',
#       'id': '3Gm5F95VdRxW3mqCn8RPBJ',
#       'name': 'Aminé',
#       'type': 'artist',
#       'uri': 'spotify:artist:3Gm5F95VdRxW3mqCn8RPBJ'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 181975,
#     'explicit': True,
#     'external_ids': {'isrc': 'USUM72010834'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1VjNQAm7bG3MLIC5Cwb508'},
#     'href': 'https://api.spotify.com/v1/tracks/1VjNQAm7bG3MLIC5Cwb508',
#     'id': '1VjNQAm7bG3MLIC5Cwb508',
#     'is_local': False,
#     'name': 'Riri',
#     'popularity': 67,
#     'preview_url': None,
#     'track_number': 9,
#     'type': 'track',
#     'uri': 'spotify:track:1VjNQAm7bG3MLIC5Cwb508'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3Gm5F95VdRxW3mqCn8RPBJ'},
#        'href': 'https://api.spotify.com/v1/artists/3Gm5F95VdRxW3mqCn8RPBJ',
#        'id': '3Gm5F95VdRxW3mqCn8RPBJ',
#        'name': 'Aminé',
#        'type': 'artist',
#        'uri': 'spotify:artist:3Gm5F95VdRxW3mqCn8RPBJ'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4mwO9qIVmngSe7yR5Ios0I'},
#      'href': 'https://api.spotify.com/v1/albums/4mwO9qIVmngSe7yR5Ios0I',
#      'id': '4mwO9qIVmngSe7yR5Ios0I',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273a52fb68f00620e45ed7467c5',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02a52fb68f00620e45ed7467c5',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851a52fb68f00620e45ed7467c5',
#        'width': 64}],
#      'name': 'ONEPOINTFIVE',
#      'release_date': '2018-08-15',
#      'release_date_precision': 'day',
#      'total_tracks': 13,
#      'type': 'album',
#      'uri': 'spotify:album:4mwO9qIVmngSe7yR5Ios0I'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3Gm5F95VdRxW3mqCn8RPBJ'},
#       'href': 'https://api.spotify.com/v1/artists/3Gm5F95VdRxW3mqCn8RPBJ',
#       'id': '3Gm5F95VdRxW3mqCn8RPBJ',
#       'name': 'Aminé',
#       'type': 'artist',
#       'uri': 'spotify:artist:3Gm5F95VdRxW3mqCn8RPBJ'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 150000,
#     'explicit': True,
#     'external_ids': {'isrc': 'USUM71811863'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1OWGLpptXlHLw1yibeHiHa'},
#     'href': 'https://api.spotify.com/v1/tracks/1OWGLpptXlHLw1yibeHiHa',
#     'id': '1OWGLpptXlHLw1yibeHiHa',
#     'is_local': False,
#     'name': 'SHINE',
#     'popularity': 66,
#     'preview_url': None,
#     'track_number': 6,
#     'type': 'track',
#     'uri': 'spotify:track:1OWGLpptXlHLw1yibeHiHa'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3Gm5F95VdRxW3mqCn8RPBJ'},
#        'href': 'https://api.spotify.com/v1/artists/3Gm5F95VdRxW3mqCn8RPBJ',
#        'id': '3Gm5F95VdRxW3mqCn8RPBJ',
#        'name': 'Aminé',
#        'type': 'artist',
#        'uri': 'spotify:artist:3Gm5F95VdRxW3mqCn8RPBJ'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4DHGT0ILYkmFmKXK9akCpq'},
#      'href': 'https://api.spotify.com/v1/albums/4DHGT0ILYkmFmKXK9akCpq',
#      'id': '4DHGT0ILYkmFmKXK9akCpq',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273653a330eec5186d92014b8bb',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02653a330eec5186d92014b8bb',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851653a330eec5186d92014b8bb',
#        'width': 64}],
#      'name': 'Compensating',
#      'release_date': '2020-07-06',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:4DHGT0ILYkmFmKXK9akCpq'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3Gm5F95VdRxW3mqCn8RPBJ'},
#       'href': 'https://api.spotify.com/v1/artists/3Gm5F95VdRxW3mqCn8RPBJ',
#       'id': '3Gm5F95VdRxW3mqCn8RPBJ',
#       'name': 'Aminé',
#       'type': 'artist',
#       'uri': 'spotify:artist:3Gm5F95VdRxW3mqCn8RPBJ'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/50co4Is1HCEo8bhOyUWKpn'},
#       'href': 'https://api.spotify.com/v1/artists/50co4Is1HCEo8bhOyUWKpn',
#       'id': '50co4Is1HCEo8bhOyUWKpn',
#       'name': 'Young Thug',
#       'type': 'artist',
#       'uri': 'spotify:artist:50co4Is1HCEo8bhOyUWKpn'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 197855,
#     'explicit': True,
#     'external_ids': {'isrc': 'USUM72013235'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1Tpn9QCsj746NNbDxQ24gr'},
#     'href': 'https://api.spotify.com/v1/tracks/1Tpn9QCsj746NNbDxQ24gr',
#     'id': '1Tpn9QCsj746NNbDxQ24gr',
#     'is_local': False,
#     'name': 'Compensating (feat. Young Thug)',
#     'popularity': 66,
#     'preview_url': None,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:1Tpn9QCsj746NNbDxQ24gr'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3Gm5F95VdRxW3mqCn8RPBJ'},
#        'href': 'https://api.spotify.com/v1/artists/3Gm5F95VdRxW3mqCn8RPBJ',
#        'id': '3Gm5F95VdRxW3mqCn8RPBJ',
#        'name': 'Aminé',
#        'type': 'artist',
#        'uri': 'spotify:artist:3Gm5F95VdRxW3mqCn8RPBJ'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2m5N05BpVj1lsHuNEz9uhf'},
#      'href': 'https://api.spotify.com/v1/albums/2m5N05BpVj1lsHuNEz9uhf',
#      'id': '2m5N05BpVj1lsHuNEz9uhf',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2737ba08104f1328b28721c30fe',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e027ba08104f1328b28721c30fe',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048517ba08104f1328b28721c30fe',
#        'width': 64}],
#      'name': 'Riri',
#      'release_date': '2020-05-29',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:2m5N05BpVj1lsHuNEz9uhf'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3Gm5F95VdRxW3mqCn8RPBJ'},
#       'href': 'https://api.spotify.com/v1/artists/3Gm5F95VdRxW3mqCn8RPBJ',
#       'id': '3Gm5F95VdRxW3mqCn8RPBJ',
#       'name': 'Aminé',
#       'type': 'artist',
#       'uri': 'spotify:artist:3Gm5F95VdRxW3mqCn8RPBJ'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 182138,
#     'explicit': True,
#     'external_ids': {'isrc': 'USUM72010834'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4qMlF2uBW2PtGSEMHPcNnZ'},
#     'href': 'https://api.spotify.com/v1/tracks/4qMlF2uBW2PtGSEMHPcNnZ',
#     'id': '4qMlF2uBW2PtGSEMHPcNnZ',
#     'is_local': False,
#     'name': 'Riri',
#     'popularity': 66,
#     'preview_url': None,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:4qMlF2uBW2PtGSEMHPcNnZ'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3Gm5F95VdRxW3mqCn8RPBJ'},
#        'href': 'https://api.spotify.com/v1/artists/3Gm5F95VdRxW3mqCn8RPBJ',
#        'id': '3Gm5F95VdRxW3mqCn8RPBJ',
#        'name': 'Aminé',
#        'type': 'artist',
#        'uri': 'spotify:artist:3Gm5F95VdRxW3mqCn8RPBJ'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6a8GwYiEMrXgMvZBvuBXrt'},
#      'href': 'https://api.spotify.com/v1/albums/6a8GwYiEMrXgMvZBvuBXrt',
#      'id': '6a8GwYiEMrXgMvZBvuBXrt',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273ea9bbdf9f1433e68c7dffbad',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02ea9bbdf9f1433e68c7dffbad',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851ea9bbdf9f1433e68c7dffbad',
#        'width': 64}],
#      'name': 'Limbo',
#      'release_date': '2020-08-07',
#      'release_date_precision': 'day',
#      'total_tracks': 14,
#      'type': 'album',
#      'uri': 'spotify:album:6a8GwYiEMrXgMvZBvuBXrt'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3Gm5F95VdRxW3mqCn8RPBJ'},
#       'href': 'https://api.spotify.com/v1/artists/3Gm5F95VdRxW3mqCn8RPBJ',
#       'id': '3Gm5F95VdRxW3mqCn8RPBJ',
#       'name': 'Aminé',
#       'type': 'artist',
#       'uri': 'spotify:artist:3Gm5F95VdRxW3mqCn8RPBJ'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/3r1XkJ7vCs8kHBSzGvPLdP'},
#       'href': 'https://api.spotify.com/v1/artists/3r1XkJ7vCs8kHBSzGvPLdP',
#       'id': '3r1XkJ7vCs8kHBSzGvPLdP',
#       'name': 'slowthai',
#       'type': 'artist',
#       'uri': 'spotify:artist:3r1XkJ7vCs8kHBSzGvPLdP'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/68kEuyFKyqrdQQLLsmiatm'},
#       'href': 'https://api.spotify.com/v1/artists/68kEuyFKyqrdQQLLsmiatm',
#       'id': '68kEuyFKyqrdQQLLsmiatm',
#       'name': 'Vince Staples',
#       'type': 'artist',
#       'uri': 'spotify:artist:68kEuyFKyqrdQQLLsmiatm'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 237500,
#     'explicit': True,
#     'external_ids': {'isrc': 'USUM72013377'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2nWB8ZpA1lxulicEUzTQ6W'},
#     'href': 'https://api.spotify.com/v1/tracks/2nWB8ZpA1lxulicEUzTQ6W',
#     'id': '2nWB8ZpA1lxulicEUzTQ6W',
#     'is_local': False,
#     'name': 'Pressure In My Palms (feat. slowthai, Vince Staples)',
#     'popularity': 66,
#     'preview_url': None,
#     'track_number': 8,
#     'type': 'track',
#     'uri': 'spotify:track:2nWB8ZpA1lxulicEUzTQ6W'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3Gm5F95VdRxW3mqCn8RPBJ'},
#        'href': 'https://api.spotify.com/v1/artists/3Gm5F95VdRxW3mqCn8RPBJ',
#        'id': '3Gm5F95VdRxW3mqCn8RPBJ',
#        'name': 'Aminé',
#        'type': 'artist',
#        'uri': 'spotify:artist:3Gm5F95VdRxW3mqCn8RPBJ'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
# ...
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6a8GwYiEMrXgMvZBvuBXrt'},
#      'href': 'https://api.spotify.com/v1/albums/6a8GwYiEMrXgMvZBvuBXrt',
#      'id': '6a8GwYiEMrXgMvZBvuBXrt',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273ea9bbdf9f1433e68c7dffbad',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02ea9bbdf9f1433e68c7dffbad',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851ea9bbdf9f1433e68c7dffbad',
#        'width': 64}],
#      'name': 'Limbo',
#      'release_date': '2020-08-07',
#      'release_date_precision': 'day',
#      'total_tracks': 14,
#      'type': 'album',
#      'uri': 'spotify:album:6a8GwYiEMrXgMvZBvuBXrt'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3Gm5F95VdRxW3mqCn8RPBJ'},
#       'href': 'https://api.spotify.com/v1/artists/3Gm5F95VdRxW3mqCn8RPBJ',
#       'id': '3Gm5F95VdRxW3mqCn8RPBJ',
#       'name': 'Aminé',
#       'type': 'artist',
#       'uri': 'spotify:artist:3Gm5F95VdRxW3mqCn8RPBJ'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/57LYzLEk2LcFghVwuWbcuS'},
#       'href': 'https://api.spotify.com/v1/artists/57LYzLEk2LcFghVwuWbcuS',
#       'id': '57LYzLEk2LcFghVwuWbcuS',
#       'name': 'Summer Walker',
#       'type': 'artist',
#       'uri': 'spotify:artist:57LYzLEk2LcFghVwuWbcuS'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 211279,
#     'explicit': True,
#     'external_ids': {'isrc': 'USUM72013388'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5AMJhqZCE2FkvbCSLlABaX'},
#     'href': 'https://api.spotify.com/v1/tracks/5AMJhqZCE2FkvbCSLlABaX',
#     'id': '5AMJhqZCE2FkvbCSLlABaX',
#     'is_local': False,
#     'name': 'Easy (feat. Summer Walker)',
#     'popularity': 61,
#     'preview_url': None,
#     'track_number': 10,
#     'type': 'track',
#     'uri': 'spotify:track:5AMJhqZCE2FkvbCSLlABaX'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3Gm5F95VdRxW3mqCn8RPBJ'},
#        'href': 'https://api.spotify.com/v1/artists/3Gm5F95VdRxW3mqCn8RPBJ',
#        'id': '3Gm5F95VdRxW3mqCn8RPBJ',
#        'name': 'Aminé',
#        'type': 'artist',
#        'uri': 'spotify:artist:3Gm5F95VdRxW3mqCn8RPBJ'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6a8GwYiEMrXgMvZBvuBXrt'},
#      'href': 'https://api.spotify.com/v1/albums/6a8GwYiEMrXgMvZBvuBXrt',
#      'id': '6a8GwYiEMrXgMvZBvuBXrt',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273ea9bbdf9f1433e68c7dffbad',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02ea9bbdf9f1433e68c7dffbad',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851ea9bbdf9f1433e68c7dffbad',
#        'width': 64}],
#      'name': 'Limbo',
#      'release_date': '2020-08-07',
#      'release_date_precision': 'day',
#      'total_tracks': 14,
#      'type': 'album',
#      'uri': 'spotify:album:6a8GwYiEMrXgMvZBvuBXrt'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3Gm5F95VdRxW3mqCn8RPBJ'},
#       'href': 'https://api.spotify.com/v1/artists/3Gm5F95VdRxW3mqCn8RPBJ',
#       'id': '3Gm5F95VdRxW3mqCn8RPBJ',
#       'name': 'Aminé',
#       'type': 'artist',
#       'uri': 'spotify:artist:3Gm5F95VdRxW3mqCn8RPBJ'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 210507,
#     'explicit': True,
#     'external_ids': {'isrc': 'USUM72013372'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/315erlcEdp5JqHqQQLQTiD'},
#     'href': 'https://api.spotify.com/v1/tracks/315erlcEdp5JqHqQQLQTiD',
#     'id': '315erlcEdp5JqHqQQLQTiD',
#     'is_local': False,
#     'name': 'Burden',
#     'popularity': 61,
#     'preview_url': None,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:315erlcEdp5JqHqQQLQTiD'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3Gm5F95VdRxW3mqCn8RPBJ'},
#        'href': 'https://api.spotify.com/v1/artists/3Gm5F95VdRxW3mqCn8RPBJ',
#        'id': '3Gm5F95VdRxW3mqCn8RPBJ',
#        'name': 'Aminé',
#        'type': 'artist',
#        'uri': 'spotify:artist:3Gm5F95VdRxW3mqCn8RPBJ'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4mwO9qIVmngSe7yR5Ios0I'},
#      'href': 'https://api.spotify.com/v1/albums/4mwO9qIVmngSe7yR5Ios0I',
#      'id': '4mwO9qIVmngSe7yR5Ios0I',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273a52fb68f00620e45ed7467c5',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02a52fb68f00620e45ed7467c5',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851a52fb68f00620e45ed7467c5',
#        'width': 64}],
#      'name': 'ONEPOINTFIVE',
#      'release_date': '2018-08-15',
#      'release_date_precision': 'day',
#      'total_tracks': 13,
#      'type': 'album',
#      'uri': 'spotify:album:4mwO9qIVmngSe7yR5Ios0I'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3Gm5F95VdRxW3mqCn8RPBJ'},
#       'href': 'https://api.spotify.com/v1/artists/3Gm5F95VdRxW3mqCn8RPBJ',
#       'id': '3Gm5F95VdRxW3mqCn8RPBJ',
#       'name': 'Aminé',
#       'type': 'artist',
#       'uri': 'spotify:artist:3Gm5F95VdRxW3mqCn8RPBJ'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 214706,
#     'explicit': True,
#     'external_ids': {'isrc': 'USUM71811896'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/45WkcBtgPS8xulUwEg63X1'},
#     'href': 'https://api.spotify.com/v1/tracks/45WkcBtgPS8xulUwEg63X1',
#     'id': '45WkcBtgPS8xulUwEg63X1',
#     'is_local': False,
#     'name': 'TOGETHER',
#     'popularity': 60,
#     'preview_url': None,
#     'track_number': 13,
#     'type': 'track',
#     'uri': 'spotify:track:45WkcBtgPS8xulUwEg63X1'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3Gm5F95VdRxW3mqCn8RPBJ'},
#        'href': 'https://api.spotify.com/v1/artists/3Gm5F95VdRxW3mqCn8RPBJ',
#        'id': '3Gm5F95VdRxW3mqCn8RPBJ',
#        'name': 'Aminé',
#        'type': 'artist',
#        'uri': 'spotify:artist:3Gm5F95VdRxW3mqCn8RPBJ'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/657XYEwejcZZ2rO0kutks8'},
#      'href': 'https://api.spotify.com/v1/albums/657XYEwejcZZ2rO0kutks8',
#      'id': '657XYEwejcZZ2rO0kutks8',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273400f50c69b125a9b9334d4e5',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02400f50c69b125a9b9334d4e5',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851400f50c69b125a9b9334d4e5',
#        'width': 64}],
#      'name': 'REDMERCEDES',
#      'release_date': '2017-03-03',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:657XYEwejcZZ2rO0kutks8'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3Gm5F95VdRxW3mqCn8RPBJ'},
#       'href': 'https://api.spotify.com/v1/artists/3Gm5F95VdRxW3mqCn8RPBJ',
#       'id': '3Gm5F95VdRxW3mqCn8RPBJ',
#       'name': 'Aminé',
#       'type': 'artist',
#       'uri': 'spotify:artist:3Gm5F95VdRxW3mqCn8RPBJ'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 169706,
#     'explicit': True,
#     'external_ids': {'isrc': 'USUG11700352'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4X70hLzIDfY5T2BcsOcv6Q'},
#     'href': 'https://api.spotify.com/v1/tracks/4X70hLzIDfY5T2BcsOcv6Q',
#     'id': '4X70hLzIDfY5T2BcsOcv6Q',
#     'is_local': False,
#     'name': 'REDMERCEDES',
#     'popularity': 61,
#     'preview_url': None,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:4X70hLzIDfY5T2BcsOcv6Q'}],
#   'limit': 20,
#   'next': 'https://api.spotify.com/v1/search?query=amine&type=track&offset=20&limit=20',
#   'offset': 0,
#   'previous': None,
#   'total': 3781}}

# %%
spotify.get_artist("3Gm5F95VdRxW3mqCn8RPBJ")
# Out:
# {'external_urls': {'spotify': 'https://open.spotify.com/artist/3Gm5F95VdRxW3mqCn8RPBJ'},
#  'followers': {'href': None, 'total': 1427826},
#  'genres': ['hip hop', 'pop rap', 'portland hip hop', 'rap'],
#  'href': 'https://api.spotify.com/v1/artists/3Gm5F95VdRxW3mqCn8RPBJ',
#  'id': '3Gm5F95VdRxW3mqCn8RPBJ',
#  'images': [{'height': 640,
#    'url': 'https://i.scdn.co/image/474d98b081007f98edd402e5889304eade75fe57',
#    'width': 640},
#   {'height': 320,
#    'url': 'https://i.scdn.co/image/b2eb77cb075bef43f55462156bbb5d2a95cca9e8',
#    'width': 320},
#   {'height': 160,
#    'url': 'https://i.scdn.co/image/ea6ae0d29cf569a6828e5153e6e0ada26c6d1bba',
#    'width': 160}],
#  'name': 'Aminé',
#  'popularity': 79,
#  'type': 'artist',
#  'uri': 'spotify:artist:3Gm5F95VdRxW3mqCn8RPBJ'}

# %%
spotify.get_album("3Gm5F95VdRxW3mqCn8RPBJ")
# Out:
# {}
